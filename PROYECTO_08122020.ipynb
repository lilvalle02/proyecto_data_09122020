# %% [markdown]
# ### Proyecto Final Bedu / Lending_club_project
#
#
# Introduction:
# Start up creada en California en 2012 cuyo modelo de negocios consiste en un “peer to peer lending” /prestamos entre particulares, sus productos están catalogados ante la SEC como “valores” , Lending Club permite a sus prestatarios crear listas de prestamos en su plataforma aportando su información personal y el financiamiento que buscan , se tratan de préstamos entre particulares que rondan los montos de $10,000 USD a $ 45,000 USD.
# Lending Club es el encargado de asignar un score a los usuarios y los financiamientos que necesitan, y en caso de contar con un buen score, Lending Club ® es el encargado de determinar las tasas de interés, el tipo de interés.
#
# *Las bases descargadas de Kaggel contienen la información de todos los créditos otorgador por Lending Club del periodo de 2015 al 2017, las hipótesis se dividen en el desde la perspectiva del cliente y desde la perspectiva de la cartera /portafolio manejado por Lending Club®
#
# (https://www.kaggle.com/wordsforthewise/lending-club)

# %%
## Analisis Exploratorio 

import pandas as pd
from pandas.util._print_versions import show_versions

# %%
df = pd.read_csv("C:/Users/Lilia Valle/Random/Desktop/ALL-LENDING-CLUB-LOAN-DATA/ALL-LENDING-CLUB-DATA-EXTRACT-EXTRACT(08122020).csv")
df.head()
# Out:
#    loan_amnt coverage investor / client        term  int_rate  installment  \
# 0       3600                       100%   36 months     13.99       123.03
# 1      12000                       100%   36 months      9.17       382.55
# 2      10000                       100%   36 months      7.91       312.95
# 3      18200                       100%   60 months     15.77       440.37
# 4      18000                       100%   36 months      6.99       555.71
#
#   grade sub_grade                          emp_title emp_length  \
# 0     C        C4                            leadman  10+ years
# 1     B        B2  Registered Veterinary Technitian     4 years
# 2     A        A5               Medical Coder/biller    2 years
# 3     D        D1              Accounting Supervisor    8 years
# 4     A        A3                              Owner  10+ years
#
#   home_ownership  ...  application_type total_rev_hi_lim bc_util mort_acc  \
# ...

# %%
data_set = pd.read_csv("C:/Users/Lilia Valle/Random/Desktop/ALL-LENDING-CLUB-LOAN-DATA/LCDataDictionary(extract).csv")
data_set
# Out:
#                    LoanStatNew  \
# 0                           id
# 1                    loan_amnt
# 2                         term
# 3                     int_rate
# 4                  installment
# 5                        grade
# 6                    sub_grade
# 7                    emp_title
# 8                   emp_length
# 9               home_ownership
# 10                  annual_inc
# 11         verification_status
# 12                     issue_d
# 13                 loan_status
# 14                  pymnt_plan
# 15                     purpose
# 16                       title
# 17                  addr_state
# 18                         dti
# 19                 delinq_2yrs
# 20            earliest_cr_line
# 21              fico_range_low
# 22             fico_range_high
# 23              inq_last_6mths
# 24                    open_acc
# 25                   revol_bal
# 26                  revol_util
# 27                   total_acc
# 28                 total_pymnt
# ...

# %%
df.head()
# Out:
#    loan_amnt coverage investor / client        term  int_rate  installment  \
# 0       3600                       100%   36 months     13.99       123.03
# 1      12000                       100%   36 months      9.17       382.55
# 2      10000                       100%   36 months      7.91       312.95
# 3      18200                       100%   60 months     15.77       440.37
# 4      18000                       100%   36 months      6.99       555.71
#
#   grade sub_grade                          emp_title emp_length  \
# 0     C        C4                            leadman  10+ years
# 1     B        B2  Registered Veterinary Technitian     4 years
# 2     A        A5               Medical Coder/biller    2 years
# 3     D        D1              Accounting Supervisor    8 years
# 4     A        A3                              Owner  10+ years
#
#   home_ownership  ...  application_type total_rev_hi_lim bc_util mort_acc  \
# ...

# %%
df.tail(5)
# Out:
#        loan_amnt coverage investor / client        term  int_rate  \
# 16489      14000                       100%   36 months     10.75
# 16490      16800                       100%   60 months     11.99
# 16491      18000                       100%   60 months     15.31
# 16492      10000                       100%   36 months      8.39
# 16493       8000                       100%   36 months      6.97
#
#        installment grade sub_grade                   emp_title emp_length  \
# 16489       456.69     B        B4                     Manager     1 year
# 16490       373.63     C        C1               Accountant II    7 years
# 16491       431.16     C        C5  Project Management Analyst    5 years
# 16492       315.17     B        B1             Legal Secretary  10+ years
# 16493       246.91     A        A3              Office Manager  10+ years
#
#       home_ownership  ...  application_type total_rev_hi_lim bc_util mort_acc  \
# ...

# %%
df.dtypes
# Out:
# loan_amnt                         int64
# coverage investor / client       object
# term                             object
# int_rate                        float64
# installment                     float64
# grade                            object
# sub_grade                        object
# emp_title                        object
# emp_length                       object
# home_ownership                   object
# annual_inc                      float64
# verification_status              object
# issue_d                          object
# loan_status                      object
# pymnt_plan                       object
# purpose                          object
# title                            object
# addr_state                       object
# name_state                       object
# dti                             float64
# delinq_2yrs                       int64
# earliest_cr_line                 object
# fico_range_low                    int64
# ...

# %%
df.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  16494.000000  16494.000000  16494.000000  1.649400e+04  16483.000000
# mean   15287.637929     12.791336    447.999295  7.795549e+04     19.351374
# std     9242.915427      4.865039    266.552484  9.697864e+04     13.495621
# min     1000.000000      5.310000     30.120000  0.000000e+00      0.000000
# 25%     8000.000000      9.170000    252.970000  4.693725e+04     12.240000
# 50%    13250.000000     12.290000    378.590000  6.500000e+04     18.360000
# 75%    20000.000000     15.610000    599.235000  9.300000e+04     25.205000
# max    40000.000000     30.990000   1531.050000  9.550000e+06    999.000000
#
#         delinq_2yrs  fico_range_low  fico_range_high  inq_last_6mths  \
# count  16494.000000    16494.000000     16494.000000    16494.000000
# mean       0.316964      698.153571       702.153632        0.517036
# std        0.885041       32.809900        32.810172        0.811184
# ...

# %%
# Cambiar el indice de loan_amount to country state

df2 = df.set_index("name_state")

df2
# Out:
#                  loan_amnt coverage investor / client        term  int_rate  \
# name_state
# Pennsylvania          3600                       100%   36 months     13.99
# California           12000                       100%   36 months      9.17
# California           10000                       100%   36 months      7.91
# Georgia              18200                       100%   60 months     15.77
# Colorado             18000                       100%   36 months      6.99
# ...                    ...                        ...         ...       ...
# Michigan             14000                       100%   36 months     10.75
# Texas                16800                       100%   60 months     11.99
# New York             18000                       100%   60 months     15.31
# Washington D.C.      10000                       100%   36 months      8.39
# California            8000                       100%   36 months      6.97
#
# ...

# %%
# Seleccionar columnas

df["name_state"]
# Out:
# 0           Pennsylvania
# 1             California
# 2             California
# 3                Georgia
# 4               Colorado
#               ...
# 16489           Michigan
# 16490              Texas
# 16491           New York
# 16492    Washington D.C.
# 16493         California
# Name: name_state, Length: 16494, dtype: object

# %%
# Tasa de interes mas alta

df[df.int_rate>=30.990000]
# Out:
#        loan_amnt coverage investor / client        term  int_rate  \
# 8519       28000                       100%   60 months     30.99
# 9125        4000                       100%   36 months     30.99
# 9177       19775                       100%   60 months     30.99
# 9369       23100                       100%   36 months     30.99
# 9906       19300                       100%   60 months     30.99
# 10265      18600                       100%   60 months     30.99
# 14118      35000                        99%   36 months     30.99
# 14333       6000                       100%   36 months     30.99
# 14381      30000                        99%   36 months     30.99
# 14464      16000                       100%   36 months     30.99
#
#        installment grade sub_grade                    emp_title emp_length  \
# 8519        923.00     G        G5         Custodial Supervisor   < 1 year
# 9125        171.99     G        G5                 Loan Auditor     1 year
# ...

# %%
# Tasa de interes mas baja

df[df.int_rate<=5.310000]
# Out:
#        loan_amnt coverage investor / client        term  int_rate  \
# 6678       30000                       100%   36 months      5.31
# 6704       20000                       100%   36 months      5.31
# 6721       12000                       100%   36 months      5.31
# 6753       10000                       100%   36 months      5.31
# 6763        1500                       100%   36 months      5.31
# 6772       10000                       100%   36 months      5.31
# 6780       20000                       100%   36 months      5.31
# 6799       13000                       100%   36 months      5.31
# 6814        4900                       100%   36 months      5.31
# 6823       15000                       100%   36 months      5.31
# 6831       14500                       100%   36 months      5.31
# 6873       13000                       100%   36 months      5.31
# 6877       12000                       100%   36 months      5.31
# ...

# %%
# Varios filtros


df[(df.home_ownership=="OWN") &(df.grade =="B") ]
# Out:
#        loan_amnt coverage investor / client        term  int_rate  \
# 42         23000                       100%   36 months      8.49
# 93         35000                       100%   60 months     10.78
# 151         7000                       100%   36 months     11.22
# 163        25000                       100%   36 months      9.76
# 203        13000                       100%   36 months      9.17
# ...          ...                        ...         ...       ...
# 16214       8000                       100%   36 months      9.75
# 16297      18000                       100%   36 months     10.75
# 16343       3000                       100%   36 months      9.16
# 16401       8500                       100%   36 months      9.75
# 16464      17000                        99%   36 months      9.16
#
#        installment grade sub_grade                              emp_title  \
# 42          725.95     B        B1                             Pharmacist
# ...

# %%
# Filtros usando un query

name_state = "California"

df.query("name_state==@name_state and grade == 'C'")
# Out:
#        loan_amnt coverage investor / client        term  int_rate  \
# 39         18000                       100%   36 months     14.85
# 47         35000                       100%   36 months     11.99
# 51         10000                       100%   36 months     13.44
# 63         30000                       100%   36 months     13.99
# 69          4200                       100%   36 months     14.85
# ...          ...                        ...         ...       ...
# 16342       3600                        93%   36 months     12.99
# 16346       7000                       100%   36 months     13.67
# 16366       5000                       100%   36 months     15.31
# 16376      10100                       100%   36 months     14.46
# 16459      15000                       100%   36 months     12.99
#
#        installment grade sub_grade                     emp_title emp_length  \
# 39          622.66     C        C5             Medical Assistant    3 years
# ...

# %%
# Cambiar el orden del data frame

df.head()
# Out:
#    loan_amnt coverage investor / client        term  int_rate  installment  \
# 0       3600                       100%   36 months     13.99       123.03
# 1      12000                       100%   36 months      9.17       382.55
# 2      10000                       100%   36 months      7.91       312.95
# 3      18200                       100%   60 months     15.77       440.37
# 4      18000                       100%   36 months      6.99       555.71
#
#   grade sub_grade                          emp_title emp_length  \
# 0     C        C4                            leadman  10+ years
# 1     B        B2  Registered Veterinary Technitian     4 years
# 2     A        A5               Medical Coder/biller    2 years
# 3     D        D1              Accounting Supervisor    8 years
# 4     A        A3                              Owner  10+ years
#
#   home_ownership  ...  application_type total_rev_hi_lim bc_util mort_acc  \
# ...

# %%
#Tabla ordenada ascendentemente por la tasa de interes

df.sort_values(by="int_rate", ascending=False)
# Out:
#        loan_amnt coverage investor / client        term  int_rate  \
# 9369       23100                       100%   36 months     30.99
# 8519       28000                       100%   60 months     30.99
# 14333       6000                       100%   36 months     30.99
# 14118      35000                        99%   36 months     30.99
# 14464      16000                       100%   36 months     30.99
# ...          ...                        ...         ...       ...
# 7004       27000                       100%   60 months      5.31
# 7097        4000                       100%   36 months      5.31
# 13470      35000                       100%   36 months      5.31
# 7183       22000                       100%   36 months      5.31
# 6753       10000                       100%   36 months      5.31
#
#        installment grade sub_grade                    emp_title emp_length  \
# 9369        993.20     G        G5      Maintenance Technician     2 years
# ...

# %%
df.sort_values(by="loan_amnt", ascending=False)
# Out:
#        loan_amnt coverage investor / client        term  int_rate  \
# 13981      40000                       100%   36 months     11.99
# 13962      40000                       100%   36 months     17.09
# 12085      40000                       100%   36 months      7.84
# 9307       40000                       100%   60 months     11.99
# 14694      40000                       100%   60 months     14.08
# ...          ...                        ...         ...       ...
# 8986        1000                       100%   36 months     22.91
# 5526        1000                       100%   36 months     12.69
# 9019        1000                       100%   36 months     12.62
# 744         1000                       100%   36 months     13.18
# 15159       1000                       100%   36 months     10.49
#
#        installment grade sub_grade                       emp_title emp_length  \
# 13981      1328.39     B        B5              Assistant Director   < 1 year
# ...

# %%
#Groupby

df.groupby("name_state").loan_amnt.sum()
# Out:
# name_state
# Alabama             2795800
# Alaska               949700
# Arizona             6448550
# Arkansas            2046075
# California         35322975
# Colorado            5477825
# Connecticut         3931550
# Delaware             594075
# Florida            17616525
# Georgia             8416300
# Hawaii              1301500
# Idaho                458875
# Illinois           10883250
# Indiana             4040075
# Kansas              1952800
# Kentucky            2396425
# Louisiana           2750850
# Maine                397050
# Maryland            5952025
# Massachusetts       5449425
# Michigan            6373175
# Minnesota           4503250
# Mississippi         1258925
# Missouri            3669000
# Montana              649100
# Nebraska            1044525
# Nevada              3300050
# New Hampshire       1045975
# New Jersey          9945075
# New Mexico          1261975
# New York           20282325
# North Carolina      7377975
# ...

# %%
# Agrupar de Data Frame en funcion del estado y la calificacion

df.groupby(["name_state", "grade"]).loan_amnt.sum()
# Out:
# name_state  grade
# Alabama     A        392750
#             B        706325
#             C        773300
#             D        521300
#             E        300900
#                       ...
# Wyoming     B        128675
#             C        173600
#             D         69250
#             E         63100
#             F         50000
# Name: loan_amnt, Length: 321, dtype: int64

# %%
# Agregar columnas

df.groupby(["grade", "int_rate"]).loan_amnt.sum()
# Out:
# grade  int_rate
# A      5.31         358900
#        5.32        7514700
#        5.93         322200
#        6.03         161400
#        6.07         344500
#                     ...
# G      30.79        238525
#        30.84        175975
#        30.89        146000
#        30.94        159550
#        30.99        199775
# Name: loan_amnt, Length: 269, dtype: int64

# %%
#Visualizacion de datos

# %load_ext watermark
# %watermark
# Out:
# Last updated: 2020-12-08T22:50:35.060822-06:00
#
# Python implementation: CPython
# Python version       : 3.7.3
# IPython version      : 7.4.0
#
# Compiler    : MSC v.1915 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel
# CPU cores   : 4
# Architecture: 64bit

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("C:/Users/Lilia Valle/Random/Desktop/ALL-LENDING-CLUB-LOAN-DATA/ALL-LENDING-CLUB-DATA-EXTRACT-EXTRACT(08122020).csv")

df.head()
# Out:
#    loan_amnt coverage investor / client        term  int_rate  installment  \
# 0       3600                       100%   36 months     13.99       123.03
# 1      12000                       100%   36 months      9.17       382.55
# 2      10000                       100%   36 months      7.91       312.95
# 3      18200                       100%   60 months     15.77       440.37
# 4      18000                       100%   36 months      6.99       555.71
#
#   grade sub_grade                          emp_title emp_length  \
# 0     C        C4                            leadman  10+ years
# 1     B        B2  Registered Veterinary Technitian     4 years
# 2     A        A5               Medical Coder/biller    2 years
# 3     D        D1              Accounting Supervisor    8 years
# 4     A        A3                              Owner  10+ years
#
#   home_ownership  ...  application_type total_rev_hi_lim bc_util mort_acc  \
# ...

# %%
df.dtypes
# Out:
# loan_amnt                         int64
# coverage investor / client       object
# term                             object
# int_rate                        float64
# installment                     float64
# grade                            object
# sub_grade                        object
# emp_title                        object
# emp_length                       object
# home_ownership                   object
# annual_inc                      float64
# verification_status              object
# issue_d                          object
# loan_status                      object
# pymnt_plan                       object
# purpose                          object
# title                            object
# addr_state                       object
# name_state                       object
# dti                             float64
# delinq_2yrs                       int64
# earliest_cr_line                 object
# fico_range_low                    int64
# ...

# %%
# crear nuevo data frame para tener una mayor calidad en los graficso


df_graph = df[['loan_amnt','int_rate','installment','grade']]

df_graph
# Out:
#        loan_amnt  int_rate  installment grade
# 0           3600     13.99       123.03     C
# 1          12000      9.17       382.55     B
# 2          10000      7.91       312.95     A
# 3          18200     15.77       440.37     D
# 4          18000      6.99       555.71     A
# ...          ...       ...          ...   ...
# 16489      14000     10.75       456.69     B
# 16490      16800     11.99       373.63     C
# 16491      18000     15.31       431.16     C
# 16492      10000      8.39       315.17     B
# 16493       8000      6.97       246.91     A
#
# [16494 rows x 4 columns]

# %%
plt.scatter(df_graph["loan_amnt"], df_graph["grade"])
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["home_ownership"], df["loan_amnt"])
plt.show()

# %%
# %matplotlib notebook

# %%
plt.scatter(df["home_ownership"], df["loan_amnt"])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# df especial pára mejorar graficos y la toma de decisiones

df_short = df[["loan_amnt", "int_rate", "grade", "home_ownership"]]

df_short
# Out:
#        loan_amnt  int_rate grade home_ownership
# 0           3600     13.99     C       MORTGAGE
# 1          12000      9.17     B       MORTGAGE
# 2          10000      7.91     A            OWN
# 3          18200     15.77     D           RENT
# 4          18000      6.99     A            OWN
# ...          ...       ...   ...            ...
# 16489      14000     10.75     B       MORTGAGE
# 16490      16800     11.99     C       MORTGAGE
# 16491      18000     15.31     C           RENT
# 16492      10000      8.39     B           RENT
# 16493       8000      6.97     A           RENT
#
# [16494 rows x 4 columns]

# %%
# Matriz de grafica de dispersion


from pandas.plotting import scatter_matrix
sm = scatter_matrix(df_short, alpha=0.2)

# %%
# Scatterplot 

import pandas as pd

# %%
df_short.head()
# Out:
#    loan_amnt  int_rate grade home_ownership
# 0       3600     13.99     C       MORTGAGE
# 1      12000      9.17     B       MORTGAGE
# 2      10000      7.91     A            OWN
# 3      18200     15.77     D           RENT
# 4      18000      6.99     A            OWN

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df_short['grade'], df_short['int_rate'])
plt.show()

# %% [markdown]
# # Analisis del Portafolio (Indicadores mas importantes)
#
# *Monto
# *Pago
# *Tasa
# *score de credito (alto y bajo)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/Lilia Valle/Random/Desktop/ALL-LENDING-CLUB-LOAN-DATA/ALL-LENDING-CLUB-DATA-EXTRACT-EXTRACT(08122020).csv")
df.head()
# Out:
#    loan_amnt coverage investor / client        term  int_rate  installment  \
# 0       3600                       100%   36 months     13.99       123.03
# 1      12000                       100%   36 months      9.17       382.55
# 2      10000                       100%   36 months      7.91       312.95
# 3      18200                       100%   60 months     15.77       440.37
# 4      18000                       100%   36 months      6.99       555.71
#
#   grade sub_grade                          emp_title emp_length  \
# 0     C        C4                            leadman  10+ years
# 1     B        B2  Registered Veterinary Technitian     4 years
# 2     A        A5               Medical Coder/biller    2 years
# 3     D        D1              Accounting Supervisor    8 years
# 4     A        A3                              Owner  10+ years
#
#   home_ownership  ...  application_type total_rev_hi_lim bc_util  mort_acc  \
# ...

# %%
df.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc          year  \
# count  16494.000000  16494.000000  16494.000000  1.649400e+04  16494.000000
# mean   15287.637929     12.791336    447.999295  7.795549e+04   2016.255790
# std     9242.915427      4.865039    266.552484  9.697864e+04      1.201563
# min     1000.000000      5.310000     30.120000  0.000000e+00   2015.000000
# 25%     8000.000000      9.170000    252.970000  4.693725e+04   2015.000000
# 50%    13250.000000     12.290000    378.590000  6.500000e+04   2016.000000
# 75%    20000.000000     15.610000    599.235000  9.300000e+04   2017.000000
# max    40000.000000     30.990000   1531.050000  9.550000e+06   2018.000000
#
#                 dti   delinq_2yrs  fico_range_low  fico_range_high  \
# count  16483.000000  16494.000000    16494.000000     16494.000000
# mean      19.351374      0.316964      698.153571       702.153632
# std       13.495621      0.885041       32.809900        32.810172
# ...

# %%
df_short1 = df[['term','loan_amnt','installment','int_rate', 'grade','purpose','fico_range_low','fico_range_high','loan_status']]

df_short1
# Out:
#              term  loan_amnt  installment  int_rate grade             purpose  \
# 0       36 months       3600       123.03     13.99     C  debt_consolidation
# 1       36 months      12000       382.55      9.17     B  debt_consolidation
# 2       36 months      10000       312.95      7.91     A  debt_consolidation
# 3       60 months      18200       440.37     15.77     D         credit_card
# 4       36 months      18000       555.71      6.99     A         credit_card
# ...           ...        ...          ...       ...   ...                 ...
# 16489   36 months      14000       456.69     10.75     B               house
# 16490   60 months      16800       373.63     11.99     C      major_purchase
# 16491   60 months      18000       431.16     15.31     C  debt_consolidation
# 16492   36 months      10000       315.17      8.39     B               house
# 16493   36 months       8000       246.91      6.97     A                 car
#
# ...

# %%
# Monto prestado 

df_short1['loan_amnt'].min()
# Out:
# 1000

# %%
df_short1['loan_amnt'].max()
# Out:
# 40000

# %%
df_short1['loan_amnt'].value_counts()
# Out:
# 10000    1282
# 20000     973
# 12000     888
# 15000     884
# 35000     670
#          ...
# 37800       1
# 7175        1
# 21550       1
# 23425       1
# 30425       1
# Name: loan_amnt, Length: 1058, dtype: int64

# %%
df_short1['loan_amnt'].value_counts()
# Out:
# 10000    1282
# 20000     973
# 12000     888
# 15000     884
# 35000     670
#          ...
# 37800       1
# 7175        1
# 21550       1
# 23425       1
# 30425       1
# Name: loan_amnt, Length: 1058, dtype: int64

# %%
sns.distplot(df_short['loan_amnt'], kde=False, norm_hist=False);
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
monto_de_prestamo_por_calificacion = df_short1.groupby('grade')['loan_amnt'].mean()
monto_de_prestamo_por_calificacion
# Out:
# grade
# A    14778.774600
# B    14582.650302
# C    15321.784887
# D    15685.445130
# E    17618.657086
# F    18973.529412
# G    20277.250000
# Name: loan_amnt, dtype: float64

# %%
monto_de_prestamo_por_dest_cred = df_short1.groupby('purpose')['loan_amnt'].mean()
monto_de_prestamo_por_dest_cred
# Out:
# purpose
# car                   10558.885542
# credit_card           15723.703041
# debt_consolidation    16067.670143
# home_improvement      14830.807623
# house                 17427.894737
# major_purchase        13216.027397
# medical                9974.386503
# moving                 8791.911765
# other                 10740.802846
# renewable_energy      10727.777778
# small_business        16101.490066
# vacation               6310.779817
# Name: loan_amnt, dtype: float64

# %%
monto_de_prestamo_por_dest_cred = df_short1.groupby('purpose')['loan_amnt'].sum()
monto_de_prestamo_por_dest_cred
# Out:
# purpose
# car                     1752775
# credit_card            61526850
# debt_consolidation    149445400
# home_improvement       16343550
# house                   1655650
# major_purchase          4823850
# medical                 1625825
# moving                  1195700
# other                  10568950
# renewable_energy          96550
# small_business          2431325
# vacation                 687875
# Name: loan_amnt, dtype: int64

# %%
monto_de_prestamo_por_plazo = df_short1.groupby('term')['loan_amnt'].mean()
monto_de_prestamo_por_plazo
# Out:
# term
#  36 months    12871.216862
#  60 months    20860.082181
# Name: loan_amnt, dtype: float64

# %%
df_short1['loan_amnt'].mean()
# Out:
# 15287.63792894386

# %%
df_short1['loan_amnt'].median()
# Out:
# 13250.0

# %%
# Percentiles y cuantiles

df_short1['loan_amnt'].min()
# Out:
# 1000

# %%
df_short1['loan_amnt'].quantile(0.25)
# Out:
# 8000.0

# %%
df_short1['loan_amnt'].quantile(0.5)
# Out:
# 13250.0

# %%
df_short1['loan_amnt'].quantile(0.75)
# Out:
# 20000.0

# %%
df_short1['loan_amnt'].max()
# Out:
# 40000

# %%
sns.boxplot(df_short1['loan_amnt']);
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Pago

df_short1['installment'].min()
# Out:
# 30.12

# %%
df_short1['installment'].max()
# Out:
# 1531.05

# %%
df_short1['installment'].value_counts()
# Out:
# 451.73    42
# 332.10    39
# 602.30    39
# 301.15    38
# 361.38    34
#           ..
# 673.23     1
# 483.25     1
# 620.09     1
# 446.77     1
# 62.00      1
# Name: installment, Length: 8062, dtype: int64

# %%
sns.distplot(df_short1['installment'], kde=False, norm_hist=False);
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_short1['installment'].mean()
# Out:
# 447.9992948951154

# %%
df_short1['installment'].median()
# Out:
# 378.59

# %%
#Percentiles y cuantiles 

df_short1['installment'].min()
# Out:
# 30.12

# %%
df_short1['installment'].quantile(0.25)
# Out:
# 252.97

# %%
df_short1['installment'].quantile(0.5)
# Out:
# 378.59

# %%
df_short1['installment'].quantile(0.75)
# Out:
# 599.2349999999999

# %%
df_short1['installment'].max()
# Out:
# 1531.05

# %%
sns.boxplot(df['installment']);
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# tasa de interes

df_short1['int_rate'].min()
# Out:
# 5.31

# %%
df_short1['int_rate'].max()
# Out:
# 30.99

# %%
df_short1['int_rate'].value_counts()
# Out:
# 5.32     510
# 11.99    496
# 7.89     444
# 9.17     361
# 13.99    335
#         ...
# 25.69      1
# 25.65      1
# 26.49      1
# 30.74      1
# 29.96      1
# Name: int_rate, Length: 253, dtype: int64

# %%
sns.distplot(df_short1['int_rate'], kde=False, norm_hist=False);
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_short1['int_rate'].mean()
# Out:
# 12.791335637201176

# %%
df_short1['int_rate'].median()
# Out:
# 12.29

# %%
#Percentiles y Cuantiles

df_short1['int_rate'].min()
# Out:
# 5.31

# %%
df_short1['int_rate'].quantile(0.25)
# Out:
# 9.17

# %%
df_short1['int_rate'].quantile(0.5)
# Out:
# 12.29

# %%
df_short1['int_rate'].quantile(0.75)
# Out:
# 15.61

# %%
df_short1['int_rate'].max()
# Out:
# 30.99

# %%
sns.boxplot(df_short1['int_rate']);
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#estatus del credito / loan_status

sns.countplot(df_short1.loan_status)
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
sns.countplot(df_short1.grade)
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %%
sns.countplot(df_short1.term)
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='term', ylabel='count'>

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')
# Out:
# <img src="data:image/png;base64,..." width="1199.999973990701">
# <AxesSubplot:>

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df_short.corr(), annot=True, cmap='YlGnBu')
# Out:
# <AxesSubplot:>
